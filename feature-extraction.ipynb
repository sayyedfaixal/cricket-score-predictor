# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# 1           NaN  Melbourne Cricket Ground
# 2           NaN  Melbourne Cricket Ground
# 3           NaN  Melbourne Cricket Ground
# 4           NaN  Melbourne Cricket Ground
# ...         ...                       ...
# 115320  Colombo       R Premadasa Stadium
# 115321  Colombo       R Premadasa Stadium
# 115322  Colombo       R Premadasa Stadium
# 115323  Colombo       R Premadasa Stadium
# 115324  Colombo       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [63888 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['current_score'] = df.groupby('match_id').cumsum()['runs']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:4805, in GroupBy.cumsum(self, axis, *args, **kwargs)
#    4802     f = lambda x: x.cumsum(axis=axis, **kwargs)
#    4803     return self._python_apply_general(f, self._selected_obj, is_transform=True)
# -> 4805 return self._cython_transform("cumsum", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1715, in DataFrameGroupBy._cython_transform(self, how, numeric_only, axis, **kwargs)
#    1709     return self.grouper._cython_operation(
#    1710         "transform", bvalues, how, 1, **kwargs
#    1711     )
#    1713 # We could use `mgr.apply` here and not have to set_axis, but
#    1714 #  we would have to do shape gymnastics for ArrayManager compat
# -> 1715 res_mgr = mgr.grouped_reduce(arr_func)
#    1716 res_mgr.set_axis(1, mgr.axes[1])
#    1718 res_df = self.obj._constructor_from_mgr(res_mgr, axes=res_mgr.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1709, in DataFrameGroupBy._cython_transform.<locals>.arr_func(bvalues)
#    1708 def arr_func(bvalues: ArrayLike) -> ArrayLike:
# -> 1709     return self.grouper._cython_operation(
#    1710         "transform", bvalues, how, 1, **kwargs
#    1711     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:339, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     336     # otherwise we have OHLC
#     337     return res.T
# --> 339 return self._call_cython_op(
#     340     values,
#     341     min_count=min_count,
#     342     ngroups=ngroups,
#     343     comp_ids=comp_ids,
#     344     mask=mask,
#     345     result_mask=result_mask,
#     346     **kwargs,
#     347 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:396, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     393         result_mask = result_mask.T
#     395 out_shape = self._get_output_shape(ngroups, values)
# --> 396 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     397 values = self._get_cython_vals(values)
#     398 out_dtype = self._get_out_dtype(values.dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:199, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     196         pass
#     197     elif "object" not in f.__signatures__:
#     198         # raise NotImplementedError here rather than TypeError later
# --> 199         raise NotImplementedError(
#     200             f"function is not implemented for this dtype: "
#     201             f"[how->{how},dtype->{dtype_str}]"
#     202         )
#     203     return f
#     204 else:
#
# NotImplementedError: function is not implemented for this dtype: [how->cumsum,dtype->object]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# 4       Melbourne
# ...           ...
# 115320    Colombo
# 115321    Colombo
# 115322    Colombo
# 115323    Colombo
# 115324    Colombo
#
# [63888 rows x 7 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city over ball_no
# 0       Melbourne    0       1
# 1       Melbourne    0       2
# 2       Melbourne    0       3
# 3       Melbourne    0       4
# 4       Melbourne    0       5
# ...           ...  ...     ...
# 115320    Colombo   19       3
# 115321    Colombo   19       4
# 115322    Colombo   19       5
# 115323    Colombo   19       6
# 115324    Colombo   19       7
#
# [63888 rows x 9 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city over ball_no  balls_bowled
# 0       Melbourne    0       1             1
# 1       Melbourne    0       2             2
# 2       Melbourne    0       3             3
# 3       Melbourne    0       4             4
# 4       Melbourne    0       5             5
# ...           ...  ...     ...           ...
# 115320    Colombo   19       3           117
# 115321    Colombo   19       4           118
# 115322    Colombo   19       5           119
# 115323    Colombo   19       6           120
# 115324    Colombo   19       7           121
#
# [63888 rows x 10 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city over ball_no  balls_bowled  balls_left
# 0       Melbourne    0       1             1         119
# 1       Melbourne    0       2             2         118
# 2       Melbourne    0       3             3         117
# 3       Melbourne    0       4             4         116
# 4       Melbourne    0       5             5         115
# ...           ...  ...     ...           ...         ...
# 115320    Colombo   19       3           117           3
# 115321    Colombo   19       4           118           2
# 115322    Colombo   19       5           119           1
# 115323    Colombo   19       6           120           0
# 115324    Colombo   19       7           121           0
#
# [63888 rows x 11 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[31], line 3
#       1 df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
#       2 df['player_dismissed'] = df['player_dismissed'].astype('int')
# ----> 3 df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
#       4 df['wickets_left'] = 10 - df['player_dismissed']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:4805, in GroupBy.cumsum(self, axis, *args, **kwargs)
#    4802     f = lambda x: x.cumsum(axis=axis, **kwargs)
#    4803     return self._python_apply_general(f, self._selected_obj, is_transform=True)
# -> 4805 return self._cython_transform("cumsum", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1715, in DataFrameGroupBy._cython_transform(self, how, numeric_only, axis, **kwargs)
#    1709     return self.grouper._cython_operation(
#    1710         "transform", bvalues, how, 1, **kwargs
#    1711     )
#    1713 # We could use `mgr.apply` here and not have to set_axis, but
#    1714 #  we would have to do shape gymnastics for ArrayManager compat
# -> 1715 res_mgr = mgr.grouped_reduce(arr_func)
#    1716 res_mgr.set_axis(1, mgr.axes[1])
#    1718 res_df = self.obj._constructor_from_mgr(res_mgr, axes=res_mgr.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1709, in DataFrameGroupBy._cython_transform.<locals>.arr_func(bvalues)
#    1708 def arr_func(bvalues: ArrayLike) -> ArrayLike:
# -> 1709     return self.grouper._cython_operation(
#    1710         "transform", bvalues, how, 1, **kwargs
#    1711     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:816, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     814 ids, _, _ = self.group_info
#     815 ngroups = self.ngroups
# --> 816 return cy_op.cython_operation(
#     817     values=values,
#     818     axis=axis,
#     819     min_count=min_count,
#     820     comp_ids=ids,
#     821     ngroups=ngroups,
#     822     **kwargs,
#     823 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:535, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     524 if not isinstance(values, np.ndarray):
#     525     # i.e. ExtensionArray
#     526     return values._groupby_op(
#     527         how=self.how,
#     528         has_dropped_na=self.has_dropped_na,
#    (...)
#     532         **kwargs,
#     533     )
# --> 535 return self._cython_op_ndim_compat(
#     536     values,
#     537     min_count=min_count,
#     538     ngroups=ngroups,
#     539     comp_ids=comp_ids,
#     540     mask=None,
#     541     **kwargs,
#     542 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:339, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     336     # otherwise we have OHLC
#     337     return res.T
# --> 339 return self._call_cython_op(
#     340     values,
#     341     min_count=min_count,
#     342     ngroups=ngroups,
#     343     comp_ids=comp_ids,
#     344     mask=mask,
#     345     result_mask=result_mask,
#     346     **kwargs,
#     347 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:396, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     393         result_mask = result_mask.T
#     395 out_shape = self._get_output_shape(ngroups, values)
# --> 396 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     397 values = self._get_cython_vals(values)
#     398 out_dtype = self._get_out_dtype(values.dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:199, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     196         pass
#     197     elif "object" not in f.__signatures__:
#     198         # raise NotImplementedError here rather than TypeError later
# --> 199         raise NotImplementedError(
#     200             f"function is not implemented for this dtype: "
#     201             f"[how->{how},dtype->{dtype_str}]"
#     202         )
#     203     return f
#     204 else:
#
# NotImplementedError: function is not implemented for this dtype: [how->cumsum,dtype->object]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 0
# 115321       964    Sri Lanka    Australia  19.4     0                 0
# 115322       964    Sri Lanka    Australia  19.5     0                 1
# 115323       964    Sri Lanka    Australia  19.6     2                 0
# 115324       964    Sri Lanka    Australia  19.7     1                 0
#
#              city over ball_no  balls_bowled  balls_left
# 0       Melbourne    0       1             1         119
# 1       Melbourne    0       2             2         118
# 2       Melbourne    0       3             3         117
# 3       Melbourne    0       4             4         116
# 4       Melbourne    0       5             5         115
# ...           ...  ...     ...           ...         ...
# 115320    Colombo   19       3           117           3
# 115321    Colombo   19       4           118           2
# 115322    Colombo   19       5           119           1
# 115323    Colombo   19       6           120           0
# 115324    Colombo   19       7           121           0
#
# [63888 rows x 11 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'current_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['crr'] = (df['current_score']*6)/df['balls_bowled']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'current_score'

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 0
# 115321       964    Sri Lanka    Australia  19.4     0                 0
# 115322       964    Sri Lanka    Australia  19.5     0                 1
# 115323       964    Sri Lanka    Australia  19.6     2                 0
# 115324       964    Sri Lanka    Australia  19.7     1                 0
#
#              city over ball_no  balls_bowled  balls_left
# 0       Melbourne    0       1             1         119
# 1       Melbourne    0       2             2         118
# 2       Melbourne    0       3             3         117
# 3       Melbourne    0       4             4         116
# 4       Melbourne    0       5             5         115
# ...           ...  ...     ...           ...         ...
# 115320    Colombo   19       3           117           3
# 115321    Colombo   19       4           118           2
# 115322    Colombo   19       5           119           1
# 115323    Colombo   19       6           120           0
# 115324    Colombo   19       7           121           0
#
# [63888 rows x 11 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:370, in BaseWindow._prep_values(self, values)
#     369     else:
# --> 370         values = ensure_float64(values)
#     371 except (ValueError, TypeError) as err:
#
# File pandas\_libs\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Australia'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:487, in BaseWindow._apply_blockwise(self, homogeneous_func, name, numeric_only)
#     486 try:
# --> 487     arr = self._prep_values(arr)
#     488 except (TypeError, NotImplementedError) as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:372, in BaseWindow._prep_values(self, values)
#     371 except (ValueError, TypeError) as err:
# --> 372     raise TypeError(f"cannot handle this type -> {values.dtype}") from err
#     374 # Convert inf to nan for C funcs
#
# TypeError: cannot handle this type -> object
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[39], line 6
#       4 last_five = []
#       5 for id in match_ids:
# ----> 6     last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:2121, in Rolling.sum(self, numeric_only, engine, engine_kwargs)
#    2052 @doc(
#    2053     template_header,
#    2054     create_section_header("Parameters"),
#    (...)
#    2119     engine_kwargs: dict[str, bool] | None = None,
#    2120 ):
# -> 2121     return super().sum(
#    2122         numeric_only=numeric_only,
#    2123         engine=engine,
#    2124         engine_kwargs=engine_kwargs,
#    2125     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:1554, in RollingAndExpandingMixin.sum(self, numeric_only, engine, engine_kwargs)
#    1552         return self._numba_apply(sliding_sum, engine_kwargs)
#    1553 window_func = window_aggregations.roll_sum
# -> 1554 return self._apply(window_func, name="sum", numeric_only=numeric_only)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:617, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     614     return result
#     616 if self.method == "single":
# --> 617     return self._apply_blockwise(homogeneous_func, name, numeric_only)
#     618 else:
#     619     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\window\rolling.py:489, in BaseWindow._apply_blockwise(self, homogeneous_func, name, numeric_only)
#     487     arr = self._prep_values(arr)
#     488 except (TypeError, NotImplementedError) as err:
# --> 489     raise DataError(
#     490         f"Cannot aggregate non-numeric type: {arr.dtype}"
#     491     ) from err
#     492 res = homogeneous_func(arr)
#     493 res_values.append(res)
#
# DataError: Cannot aggregate non-numeric type: object

# %%
df['last_five'] = last_five
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['last_five'] = last_five
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5039, in DataFrame._sanitize_column(self, value)
#    5036     return _reindex_for_setitem(value, self.index)
#    5038 if is_list_like(value):
# -> 5039     com.require_length_match(value, self.index)
#    5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (0) does not match length of index (63888)

# %%
# df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','']]
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [50501 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6179, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['current_score', 'wickets_left', 'crr', 'last_five'] not in index"

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# match_id            0
# runs_x              0
# batting_team        0
# bowling_team        0
# ball                0
# runs_y              0
# player_dismissed    0
# city                0
# over                0
# ball_no             0
# balls_bowled        0
# balls_left          0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#        match_id  runs_x batting_team  bowling_team  ball  runs_y  \
# 55121       822     191      England   New Zealand  19.4       1
# 7104         89     172        India  South Africa  14.4       0
#
#        player_dismissed        city over ball_no  balls_bowled  balls_left
# 55121                 0  Manchester   19       4           118           2
# 7104                  0   Cape Town   14       4            88          32

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        match_id  batting_team  bowling_team  ball  runs_y  player_dismissed  \
# 12530       157      Pakistan     Australia  19.2       1                 0
# 57062       859  South Africa     Australia  13.4       1                 0
# 3636         53      Pakistan   West Indies   2.1       0                 0
# 51670       788      Pakistan     Australia  10.3       4                 0
# 4108         56      Pakistan   West Indies  18.2       1                 0
# ...         ...           ...           ...   ...     ...               ...
# 46444       708      Pakistan  South Africa   1.3       0                 0
# 19241       308      Pakistan       England   4.6       1                 0
# 2462         31   New Zealand     Australia  14.3       0                 0
# 26118       484         India     Australia  11.2       1                 0
# 16809       242   New Zealand       England   0.1       0                 0
#
#                city over ball_no  balls_bowled  balls_left
# 12530         Dubai   19       2           116           4
# 57062  Johannesburg   13       4            82          38
# 3636       Trinidad    2       1            13         107
# 51670        Mirpur   10       3            63          57
# 4108       Trinidad   18       2           110          10
# ...             ...  ...     ...           ...         ...
# 46444     Centurion    1       3             9         111
# 19241    Manchester    4       6            30          90
# 2462         Sydney   14       3            87          33
# 26118     Melbourne   11       2            68          52
# 16809      Auckland    0       1             1         119
#
# [51110 rows x 11 columns]

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\sayed\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\sayed\anaconda3\lib\site-packages (from xgboost) (1.11.4)
# Downloading xgboost-2.1.2-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 330.3 kB/s eta 0:06:19
#    ---------------------------------------- 0.1/124.9 MB 655.4 kB/s eta 0:03:11
#    ---------------------------------------- 0.4/124.9 MB 2.5 MB/s eta 0:00:50
#    ---------------------------------------- 0.9/124.9 MB 4.3 MB/s eta 0:00:29
#    ---------------------------------------- 1.6/124.9 MB 6.2 MB/s eta 0:00:20
#     --------------------------------------- 2.2/124.9 MB 7.3 MB/s eta 0:00:17
#     --------------------------------------- 2.8/124.9 MB 8.0 MB/s eta 0:00:16
#    - -------------------------------------- 3.4/124.9 MB 9.0 MB/s eta 0:00:14
MB 4.0 MB/s eta 0:00:24
#    --------- ------------------------------ 30.2/124.9 MB 3.9 MB/s eta 0:00:25
#    --------- ------------------------------ 30.2/124.9 MB 3.9 MB/s eta 0:00:25
#    --------- ------------------------------ 30.2/124.9 MB 3.9 MB/s eta 0:00:25
#    --------- ------------------------------ 30.2/124.9 MB 3.8 MB/s eta 0:00:26
#    --------- ------------------------------ 30.3/124.9 MB 3.7 MB/s eta 0:00:26
#    --------- ------------------------------ 30.3/124.9 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 30.4/124.9 MB 3.6 MB/s eta 0:00:27
#    --------- ------------------------------ 30.4/124.9 MB 3.5 MB/s eta 0:00:27
#    --------- ------------------------------ 30.5/124.9 MB 3.5 MB/s eta 0:00:28
#    --------- ------------------------------ 30.5/124.9 MB 3.4 MB/s eta 0:00:28
#    --------- ------------------------------ 30.6/124.9 MB 3.4 MB/s eta 0:00:28
#    --------- ------------------------------ 30.6/124.9 MB 3.3 MB/s eta 0:00:29
#    --------- ------------------------------ 30.7/124.9 MB 3.3 MB/s eta 0:00:29
#    --------- ------------------------------ 30.8/124.9 MB 3.3 MB/s eta 0:00:29
#    --------- ------------------------------ 30.9/124.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 30.9/124.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 31.0/124.9 MB 3.2 MB/s eta 0:00:30
#    --------- ------------------------------ 31.1/124.9 MB 3.1 MB/s eta 0:00:30
#    --------- ------------------------------ 31.2/124.9 MB 3.1 MB/s eta 0:00:31
#    ---------- ----------------------------- 31.3/124.9 MB 3.1 MB/s eta 0:00:31
#    ---------- ----------------------------- 31.3/124.9 MB 3.0 MB/s eta 0:00:31
#    ---------- ----------------------------- 31.4/124.9 MB 3.0 MB/s eta 0:00:32
#    ---------- ----------------------------- 31.5/124.9 MB 3.0 MB/s eta 0:00:32
#    ---------- ----------------------------- 31.6/124.9 MB 2.9 MB/s eta 0:00:32
#    ---------- ----------------------------- 31.7/124.9 MB 2.9 MB/s eta 0:00:33
#    ---------- ----------------------------- 31.8/124.9 MB 2.9 MB/s eta 0:00:33
#    ---------- ----------------------------- 31.9/124.9 MB 2.9 MB/s eta 0:00:33
#    ---------- ----------------------------- 32.0/124.9 MB 2.8 MB/s eta 0:00:33
#    ---------- ----------------------------- 32.1/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 32.2/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 32.3/124.9 MB 2.8 MB/s eta 0:00:34
#    ---------- ----------------------------- 32.4/124.9 MB 2.7 MB/s eta 0:00:34
#    ---------- ----------------------------- 32.6/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 32.7/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 32.8/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 33.0/124.9 MB 2.7 MB/s eta 0:00:35
#    ---------- ----------------------------- 33.1/124.9 MB 2.6 MB/s eta 0:00:35
#    ---------- ----------------------------- 33.2/124.9 MB 2.6 MB/s eta 0:00:36
#    ---------- ----------------------------- 33.4/124.9 MB 2.6 MB/s eta 0:00:36
#    ---------- ----------------------------- 33.4/124.9 MB 2.6 MB/s eta 0:00:36
#    ---------- ----------------------------- 33.6/124.9 MB 2.6 MB/s eta 0:00:36
#    ---------- ----------------------------- 33.7/124.9 MB 2.5 MB/s eta 0:00:36
#    ---------- ----------------------------- 33.8/124.9 MB 2.5 MB/s eta 0:00:37
#    ---------- ----------------------------- 33.9/124.9 MB 2.5 MB/s eta 0:00:37
#    ---------- ----------------------------- 34.0/124.9 MB 2.5 MB/s eta 0:00:37
#    ---------- ----------------------------- 34.2/124.9 MB 2.5 MB/s eta 0:00:37
#    ---------- ----------------------------- 34.3/124.9 MB 2.5 MB/s eta 0:00:37
#    ----------- ---------------------------- 34.4/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 34.5/124.9 MB 2.5 MB/s eta 0:00:37
#    ----------- ---------------------------- 34.7/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 34.8/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.0/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.2/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.4/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.5/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.7/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 35.9/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 36.0/124.9 MB 2.5 MB/s eta 0:00:36
#    ----------- ---------------------------- 36.1/124.9 MB 2.5 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.4/124.9 MB 2.5 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.6/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.7/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 36.9/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 37.1/124.9 MB 2.6 MB/s eta 0:00:35
#    ----------- ---------------------------- 37.3/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 37.6/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 37.8/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 37.9/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 38.1/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 38.4/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 38.5/124.9 MB 2.6 MB/s eta 0:00:33
#    ------------ --------------------------- 38.8/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 38.9/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 39.0/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 39.1/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 39.2/124.9 MB 2.6 MB/s eta 0:00:34
#    ------------ --------------------------- 39.3/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 39.5/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 39.7/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 39.8/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 40.0/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 40.1/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 40.3/124.9 MB 2.5 MB/s eta 0:00:34
#    ------------ --------------------------- 40.4/124.9 MB 2.6 MB/s eta 0:00:33
#    ------------ --------------------------- 40.6/124.9 MB 2.7 MB/s eta 0:00:32
#    ------------- -------------------------- 40.7/124.9 MB 2.8 MB/s eta 0:00:30
#    ------------- --------------------------